# %% [markdown]
# ## Data Analysis Trade IronFX ('Broker')

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Encontrar un patron en los datos tal que pueda predecir que tipo de operaciones en divisas son más probables a ser ganadoras y entender cuál fue el problemas en los trades perdedores.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dft0=pd.read_csv('diario_trading_real.csv', decimal=',')
dft0
# Out:
#                Time_open  Type  Size       Symbol Price_open      S/L  \
# 0    2021/03/31 12:00:14  sell  0.01   gbpusd_M15    1.37986  1.38092
# 1    2021/03/31 12:31:33   buy  0.03   usdjpy_M15    110.657   110.53
# 2    2021/03/31 12:33:46  sell  0.03    gpbusd_M5    1.37972  1.38072
# 3    2021/03/31 16:11:22  sell  0.03   usdjpy_M15    110.663  110.822
# 4    2021/03/31 19:56:49   buy  0.03   usdchf_M30    0.94478  0.94357
# ..                   ...   ...   ...          ...        ...      ...
# 330  2022/04/25 12:19:32   buy  0.01  uk100_m2_H1       7382     7322
# 331  2022/04/28 17:44:31  sell  0.01    usdjpy_H1    130.825  131.342
# 332  2022/05/05 10:02:04  sell  0.01   wticash_H1     107.24   109.46
# 333  2022/05/09 14:01:15   buy  0.01  ger40_m2_H1      13475    13336
# 334  2022/05/23 12:30:42  sell  0.01    nzdusd_H1    0.64566  0.64959
#
#          T/P           Time_close Price_close   Swap Profit  \
# 0    1.37825  2021/03/31 12:11:11     1.38092      0  -1.06
# 1     110.71  2021/03/31 13:10:36      110.71      0   1.44
# 2    1.37864  2021/03/31 13:24:21     1.37864      0   3.24
# 3     110.56  2021/03/31 18:08:40     110.822      0   -4.3
# 4    0.94533  2021/03/31 11:23:01     0.94533      0   1.75
# ..       ...                  ...         ...    ...    ...
# 330     7442   2022/04/26 1:00:03        7442  -0.03   7.65
# 331  130.237   2022/04/29 1:23:21     130.237      0   4.51
# 332   105.02  2022/05/05 16:28:07      109.46  -0.55  -22.2
# 333    13622   2022/05/10 3:38:38       13622  -0.05  38.83
# 334  0.64173  2022/05/24 21:06:17     0.64959  -0.06  -3.93
#
#                Comment Unnamed: 12
# 0    Me senti relajado         NaN
# 1        senti control         NaN
# 2        sentí control         NaN
# 3       Senti relajado         NaN
# 4        Senti control         NaN
# ..                 ...         ...
# 330        Cabeza fría         NaN
# 331        Cabeza fria         NaN
# 332        Cabeza fría         NaN
# 333        Cabeza fría         NaN
# 334        Cabeza fría         NaN
#
# [335 rows x 13 columns]

# %%
dft0.drop('Unnamed: 12', inplace=True, axis=1)

# %%
dft0
# Out:
#                Time_open  Type  Size       Symbol Price_open      S/L  \
# 0    2021/03/31 12:00:14  sell  0.01   gbpusd_M15    1.37986  1.38092
# 1    2021/03/31 12:31:33   buy  0.03   usdjpy_M15    110.657   110.53
# 2    2021/03/31 12:33:46  sell  0.03    gpbusd_M5    1.37972  1.38072
# 3    2021/03/31 16:11:22  sell  0.03   usdjpy_M15    110.663  110.822
# 4    2021/03/31 19:56:49   buy  0.03   usdchf_M30    0.94478  0.94357
# ..                   ...   ...   ...          ...        ...      ...
# 330  2022/04/25 12:19:32   buy  0.01  uk100_m2_H1       7382     7322
# 331  2022/04/28 17:44:31  sell  0.01    usdjpy_H1    130.825  131.342
# 332  2022/05/05 10:02:04  sell  0.01   wticash_H1     107.24   109.46
# 333  2022/05/09 14:01:15   buy  0.01  ger40_m2_H1      13475    13336
# 334  2022/05/23 12:30:42  sell  0.01    nzdusd_H1    0.64566  0.64959
#
#          T/P           Time_close Price_close   Swap Profit            Comment
# 0    1.37825  2021/03/31 12:11:11     1.38092      0  -1.06  Me senti relajado
# 1     110.71  2021/03/31 13:10:36      110.71      0   1.44      senti control
# 2    1.37864  2021/03/31 13:24:21     1.37864      0   3.24      sentí control
# 3     110.56  2021/03/31 18:08:40     110.822      0   -4.3     Senti relajado
# 4    0.94533  2021/03/31 11:23:01     0.94533      0   1.75      Senti control
# ..       ...                  ...         ...    ...    ...                ...
# 330     7442   2022/04/26 1:00:03        7442  -0.03   7.65        Cabeza fría
# 331  130.237   2022/04/29 1:23:21     130.237      0   4.51        Cabeza fria
# 332   105.02  2022/05/05 16:28:07      109.46  -0.55  -22.2        Cabeza fría
# 333    13622   2022/05/10 3:38:38       13622  -0.05  38.83        Cabeza fría
# 334  0.64173  2022/05/24 21:06:17     0.64959  -0.06  -3.93        Cabeza fría
#
# [335 rows x 12 columns]

# %%
dft0['Type'].unique()
# Out:
# array(['sell', 'buy', 'sell ', 'sel', 'buy '], dtype=object)

# %%
type1={'sell':'sell', 'buy':'buy', 'sel':'sell', 'buy ':'buy'}

# %%
dft0['Type']=dft0['Type'].map(type1)
dft0.groupby('Type').size()
# Out:
# Type
# buy     164
# sell    167
# dtype: int64

# %% [markdown]
# Hay que tener en cuenta que durante un año de trading se realizarón más ordenes de venta que de compra

# %%
dft0['Symbol']
# Out:
# 0       gbpusd_M15
# 1       usdjpy_M15
# 2        gpbusd_M5
# 3       usdjpy_M15
# 4       usdchf_M30
#           ...
# 330    uk100_m2_H1
# 331      usdjpy_H1
# 332     wticash_H1
# 333    ger40_m2_H1
# 334      nzdusd_H1
# Name: Symbol, Length: 335, dtype: object

# %% [markdown]
# podemos ver en la columna de "Symbol" que se encuentra el par de divisas que se realizo la operación junto con un distintivo M (minutos) y H (horas). Procederemos a realizar esa separación para tener más precisión en el análisis

# %%
dft0[['Symbol_only','temporality0','temporality1','temporality2']]=dft0['Symbol'].str.split('_', expand=True)
dft0
# Out:
#                Time_open  Type  Size       Symbol Price_open      S/L  \
# 0    2021/03/31 12:00:14  sell  0.01   gbpusd_M15    1.37986  1.38092
# 1    2021/03/31 12:31:33   buy  0.03   usdjpy_M15    110.657   110.53
# 2    2021/03/31 12:33:46  sell  0.03    gpbusd_M5    1.37972  1.38072
# 3    2021/03/31 16:11:22  sell  0.03   usdjpy_M15    110.663  110.822
# 4    2021/03/31 19:56:49   buy  0.03   usdchf_M30    0.94478  0.94357
# ..                   ...   ...   ...          ...        ...      ...
# 330  2022/04/25 12:19:32   buy  0.01  uk100_m2_H1       7382     7322
# 331  2022/04/28 17:44:31  sell  0.01    usdjpy_H1    130.825  131.342
# 332  2022/05/05 10:02:04  sell  0.01   wticash_H1     107.24   109.46
# 333  2022/05/09 14:01:15   buy  0.01  ger40_m2_H1      13475    13336
# 334  2022/05/23 12:30:42  sell  0.01    nzdusd_H1    0.64566  0.64959
#
#          T/P           Time_close Price_close   Swap Profit  \
# 0    1.37825  2021/03/31 12:11:11     1.38092      0  -1.06
# 1     110.71  2021/03/31 13:10:36      110.71      0   1.44
# 2    1.37864  2021/03/31 13:24:21     1.37864      0   3.24
# 3     110.56  2021/03/31 18:08:40     110.822      0   -4.3
# 4    0.94533  2021/03/31 11:23:01     0.94533      0   1.75
# ..       ...                  ...         ...    ...    ...
# 330     7442   2022/04/26 1:00:03        7442  -0.03   7.65
# 331  130.237   2022/04/29 1:23:21     130.237      0   4.51
# 332   105.02  2022/05/05 16:28:07      109.46  -0.55  -22.2
# 333    13622   2022/05/10 3:38:38       13622  -0.05  38.83
# 334  0.64173  2022/05/24 21:06:17     0.64959  -0.06  -3.93
#
#                Comment Symbol_only temporality0 temporality1 temporality2
# 0    Me senti relajado      gbpusd          M15         None         None
# 1        senti control      usdjpy          M15         None         None
# 2        sentí control      gpbusd           M5         None         None
# 3       Senti relajado      usdjpy          M15         None         None
# 4        Senti control      usdchf          M30         None         None
# ..                 ...         ...          ...          ...          ...
# 330        Cabeza fría       uk100           m2           H1         None
# 331        Cabeza fria      usdjpy           H1         None         None
# 332        Cabeza fría     wticash           H1         None         None
# 333        Cabeza fría       ger40           m2           H1         None
# 334        Cabeza fría      nzdusd           H1         None         None
#
# [335 rows x 16 columns]

# %%
dft0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Time_open     335 non-null    object
#  1   Type          331 non-null    object
#  2   Size          335 non-null    object
#  3   Symbol        335 non-null    object
#  4   Price_open    335 non-null    object
#  5   S/L           335 non-null    object
#  6   T/P           335 non-null    object
#  7   Time_close    335 non-null    object
#  8   Price_close   335 non-null    object
#  9   Swap          335 non-null    object
#  10  Profit        335 non-null    object
#  11  Comment       335 non-null    object
#  12  Symbol_only   335 non-null    object
#  13  temporality0  334 non-null    object
#  14  temporality1  88 non-null     object
#  15  temporality2  22 non-null     object
# dtypes: object(16)
# memory usage: 42.0+ KB

# %% [markdown]
# En la lista anterior observamos que los registros que contienen tipo de dato numerico se encuntran categorizados como tipo objeto, realizamos una transformación a este tipo de datos para poder realizar la aritmetica correspondiente

# %%
data_transform_obj_float=['Size', 'Price_open', 'S/L', 'T/P', 'Price_close', 'Swap', 'Profit']
for i in data_transform_obj_float:
    dft0[i]=dft0[i].astype('float64')

# %%
#transform_data_num
dft0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Time_open     335 non-null    object
#  1   Type          331 non-null    object
#  2   Size          335 non-null    float64
#  3   Symbol        335 non-null    object
#  4   Price_open    335 non-null    float64
#  5   S/L           335 non-null    float64
#  6   T/P           335 non-null    float64
#  7   Time_close    335 non-null    object
#  8   Price_close   335 non-null    float64
#  9   Swap          335 non-null    float64
#  10  Profit        335 non-null    float64
#  11  Comment       335 non-null    object
#  12  Symbol_only   335 non-null    object
#  13  temporality0  334 non-null    object
#  14  temporality1  88 non-null     object
#  15  temporality2  22 non-null     object
# dtypes: float64(7), object(9)
# memory usage: 42.0+ KB

# %% [markdown]
# Ahora que realizamos el cambio de tipo de variable, he logrado notar que los datos del tiempo se encuentran de tipo object y la intención aquí es dejarlo de tipo data_time para mayor comodidad de operación

# %%
data_transform_time=['Time_open', 'Time_close']
for j in data_transform_time:
    dft0[j]=pd.to_datetime(dft0[j])

# %%
dft0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Time_open     335 non-null    datetime64[ns]
#  1   Type          331 non-null    object
#  2   Size          335 non-null    float64
#  3   Symbol        335 non-null    object
#  4   Price_open    335 non-null    float64
#  5   S/L           335 non-null    float64
#  6   T/P           335 non-null    float64
#  7   Time_close    335 non-null    datetime64[ns]
#  8   Price_close   335 non-null    float64
#  9   Swap          335 non-null    float64
#  10  Profit        335 non-null    float64
#  11  Comment       335 non-null    object
#  12  Symbol_only   335 non-null    object
#  13  temporality0  334 non-null    object
#  14  temporality1  88 non-null     object
#  15  temporality2  22 non-null     object
# dtypes: datetime64[ns](2), float64(7), object(7)
# memory usage: 42.0+ KB

# %% [markdown]
# La conversión a un tipo de datos manejable desde pandas nos evidencio impureza en los datos a la hora de la digitación. Lo que conllevo a realizar ciertas correcciones desde la base de datos de donde se encuentra el rep

# %%
dft0['temporality0'].unique()
# Out:
# array(['M15', 'M5', 'M30', 'H1', 'm1', 'k1', 'gas', '', 'H4', None, 'n1',
#        'u1', '20', 'z1', 'h2', 'm2'], dtype=object)

# %%
arr_temp0=['m1','k1','n1','u1','z1','h2','m2']

# %%
column_temp0=dft0[dft0['temporality0'].isin(arr_temp0)][['temporality0']]

# %%
column_temp1=dft0[dft0['temporality0'].isin(arr_temp0)][['temporality1']]
#column_temp1

# %%
column_aux=column_temp1.copy()
#column_aux

# %%
dft0_aux=dft0[dft0['temporality0'].isin(arr_temp0)].copy()
dft0_aux['temporality0']=column_aux
dft0_aux
# Out:
#               Time_open  Type  Size         Symbol  Price_open         S/L  \
# 8   2021-04-01 14:01:22  sell  0.01    us500_m1_H1   4000.5000   4004.5000
# 25  2021-04-07 08:41:28   buy  0.01  nat.gas_k1_H1      2.5020      2.4480
# 28  2021-04-07 10:02:12   buy  0.01     us30_m1_H1  33347.0000  33284.0000
# 29  2021-04-07 10:04:39   buy  0.01    us500_m1_H1   4071.7500   4060.2500
# 30  2021-04-07 10:06:15   buy  0.01    us100_m1_H1  13628.5000  13507.2500
# ..                  ...   ...   ...            ...         ...         ...
# 326 2022-04-25 08:43:28   buy  0.01     us30_m2_H1  33521.0000  33269.0000
# 328 2022-04-25 12:16:52   buy  0.01      gbp_m2_H1      1.2732      1.2679
# 329 2022-04-25 12:17:25   buy  0.01    ger40_m2_H1  14020.0000  13897.5000
# 330 2022-04-25 12:19:32   buy  0.01    uk100_m2_H1   7382.0000   7322.0000
# 333 2022-05-09 14:01:15   buy  0.01    ger40_m2_H1  13475.0000  13336.0000
#
#             T/P          Time_close  Price_close  Swap  Profit  \
# 8     3992.7500 2021-04-01 14:48:26    4004.5000  0.00   -2.00
# 25       2.5470 2021-04-07 09:27:49       2.5470  0.00   14.65
# 28   33427.0000 2021-04-07 10:27:24   33284.0000  0.00   -3.15
# 29    4082.5000 2021-04-07 10:40:07    4060.2500  0.00   -5.75
# 30   13761.0000 2021-04-07 18:33:45   13634.2500 -0.12    1.15
# ..          ...                 ...          ...   ...     ...
# 326  33782.0000 2022-04-25 10:47:40   33269.0000  0.00  -12.60
# 328      1.2789 2022-04-26 07:16:55       1.2679 -0.03   -3.31
# 329  14147.0000 2022-04-26 01:00:03   14147.0000 -0.05   34.07
# 330   7442.0000 2022-04-26 01:00:03    7442.0000 -0.03    7.65
# 333  13622.0000 2022-05-10 03:38:38   13622.0000 -0.05   38.83
#
#                      Comment Symbol_only temporality0 temporality1  \
# 8              Senti control       us500           H1           H1
# 25   Realajado y Cabeza fria     nat.gas           H1           H1
# 28               Cabeza fría        us30           H1           H1
# 29               Cabeza fria       us500           H1           H1
# 30               Cabeza fria       us100           H1           H1
# ..                       ...         ...          ...          ...
# 326              Cabeza fría        us30           H1           H1
# 328              Cabeza fría         gbp           H1           H1
# 329              Cabeza fría       ger40           H1           H1
# 330              Cabeza fría       uk100           H1           H1
# 333              Cabeza fría       ger40           H1           H1
#
#     temporality2
# 8           None
# 25          None
# 28          None
# 29          None
# 30          None
# ..           ...
# 326         None
# 328         None
# 329         None
# 330         None
# 333         None
#
# [65 rows x 16 columns]

# %%
dft0_aux2=dft0.copy()
dft0_aux2
# Out:
#               Time_open  Type  Size       Symbol   Price_open          S/L  \
# 0   2021-03-31 12:00:14  sell  0.01   gbpusd_M15      1.37986      1.38092
# 1   2021-03-31 12:31:33   buy  0.03   usdjpy_M15    110.65700    110.53000
# 2   2021-03-31 12:33:46  sell  0.03    gpbusd_M5      1.37972      1.38072
# 3   2021-03-31 16:11:22  sell  0.03   usdjpy_M15    110.66300    110.82200
# 4   2021-03-31 19:56:49   buy  0.03   usdchf_M30      0.94478      0.94357
# ..                  ...   ...   ...          ...          ...          ...
# 330 2022-04-25 12:19:32   buy  0.01  uk100_m2_H1   7382.00000   7322.00000
# 331 2022-04-28 17:44:31  sell  0.01    usdjpy_H1    130.82500    131.34200
# 332 2022-05-05 10:02:04  sell  0.01   wticash_H1    107.24000    109.46000
# 333 2022-05-09 14:01:15   buy  0.01  ger40_m2_H1  13475.00000  13336.00000
# 334 2022-05-23 12:30:42  sell  0.01    nzdusd_H1      0.64566      0.64959
#
#              T/P          Time_close  Price_close  Swap  Profit  \
# 0        1.37825 2021-03-31 12:11:11      1.38092  0.00   -1.06
# 1      110.71000 2021-03-31 13:10:36    110.71000  0.00    1.44
# 2        1.37864 2021-03-31 13:24:21      1.37864  0.00    3.24
# 3      110.56000 2021-03-31 18:08:40    110.82200  0.00   -4.30
# 4        0.94533 2021-03-31 11:23:01      0.94533  0.00    1.75
# ..           ...                 ...          ...   ...     ...
# 330   7442.00000 2022-04-26 01:00:03   7442.00000 -0.03    7.65
# 331    130.23700 2022-04-29 01:23:21    130.23700  0.00    4.51
# 332    105.02000 2022-05-05 16:28:07    109.46000 -0.55  -22.20
# 333  13622.00000 2022-05-10 03:38:38  13622.00000 -0.05   38.83
# 334      0.64173 2022-05-24 21:06:17      0.64959 -0.06   -3.93
#
#                Comment Symbol_only temporality0 temporality1 temporality2
# 0    Me senti relajado      gbpusd          M15         None         None
# 1        senti control      usdjpy          M15         None         None
# 2        sentí control      gpbusd           M5         None         None
# 3       Senti relajado      usdjpy          M15         None         None
# 4        Senti control      usdchf          M30         None         None
# ..                 ...         ...          ...          ...          ...
# 330        Cabeza fría       uk100           m2           H1         None
# 331        Cabeza fria      usdjpy           H1         None         None
# 332        Cabeza fría     wticash           H1         None         None
# 333        Cabeza fría       ger40           m2           H1         None
# 334        Cabeza fría      nzdusd           H1         None         None
#
# [335 rows x 16 columns]

# %%
dft0_aux2.loc[dft0_aux2['temporality0'].isin(arr_temp0),column_aux]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [89], in <cell line: 1>()
# ----> 1 dft0_aux2.loc[dft0_aux2['temporality0'].isin(arr_temp0),column_aux]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1189, in _LocIndexer._getitem_axis(self, key, axis)
#    1186 if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
# -> 1189         raise ValueError("Cannot index with multidimensional key")
#    1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#
# ValueError: Cannot index with multidimensional key
